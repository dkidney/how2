# %% [markdown]
# # datetime

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # get the current time

# %%
#current_time = dt.datetime.utcnow() # deprecated
current_time = dt.datetime.now(dt.timezone.utc)
current_time
# Out:
# datetime.datetime(2025, 11, 5, 11, 46, 8, 870320, tzinfo=datetime.timezone.utc)

# %%
current_time.date()
# Out:
# datetime.date(2025, 11, 5)

# %% [markdown]
# # convert datetime to string

# %%
current_time.strftime('%Y-%m-%d')
# Out:
# '2025-11-05'

# %% [markdown]
# # convert string to datetime

# %%
dt.datetime.strptime('2000-12-31', '%Y-%m-%d')
# Out:
# datetime.datetime(2000, 12, 31, 0, 0)

# %% [markdown]
# # add time difference

# %%
(current_time + dt.timedelta(365)).date() # can only use day units
# Out:
# datetime.date(2026, 11, 5)

# %%
(current_time + relativedelta(years=1)).date() # allows alternative units
# Out:
# datetime.date(2026, 11, 5)

# %% [markdown]
# # bespoke function

# %%
def date_add(date, **kwargs):
    old_date = dt.datetime.strptime(date, '%Y-%m-%d').date()
    new_date = old_date + relativedelta(**kwargs)
    return new_date.strftime('%Y-%m-%d')

# %%
today = '2025-11-05'
print(date_add(today, years=1))
print(date_add(today, years=-1))
print(date_add(today, years=-1, days=1))
# Out:
# 2026-11-05
# 2024-11-05
# 2024-11-06
